# %%
from matplotlib import pyplot as plt
import matplotlib
a=sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist])

for i in a:
    if('hei' in i or 'Hei' in i):
        print(i)
# Out:
# Hei
# Heiti TC
# Heiti TC
# Lantinghei SC
# LiHei Pro
# STHeiti
# STHeiti
# SimHei

# %%
from matplotlib_inline import backend_inline
backend_inline.set_matplotlib_formats('svg')
from pylab import *
rcParams['font.family'] = 'DejaVu Sans','SimHei'

# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharey=True)

# fig = plt.figure(figsize=(6,6), dpi=80)
fig, ((ax1, ax2), (ax3, ax4)) = subplots(2, 2, figsize=(6, 6), sharex=True, sharey=True)
ax1.text(0.5, 0.5, 'ax1', fontsize=18, ha='center')
ax2.text(0.5, 0.5, 'ax2', fontsize=18, ha='center')
ax3.text(0.5, 0.5, 'ax3', fontsize=18, ha='center')
ax4.text(0.5, 0.5, 'ax4', fontsize=18, ha='center')

# ax.set(xlim=[0.5, 4.5], ylim=[-2, 8], title='An Example Axes', ylabel='Y-Axis', xlabel='X-Axis') 
show()

# %%
fig = plt.figure(figsize=(6,6), dpi=80)
ax1 = fig.add_subplot(2,2,1)
ax1.text(0.5, 0.5, 'ax1', fontsize=18, ha='center')
ax2 = fig.add_subplot(222)
ax2.text(0.5, 0.5, 'ax2', fontsize=18, ha='center')
ax3 = fig.add_subplot(223)
ax3.text(0.5, 0.5, 'ax3', fontsize=18, ha='center')
ax4 = fig.add_subplot(224)
ax4.text(0.5, 0.5, 'ax4', fontsize=18, ha='center')
show()

# %%
from pylab import *

n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x,y in zip(X,Y1):
    text(x, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

for x, y in zip(X, Y2):
    text(x, -y-0.05, '%.2f' % abs(y), ha='center', va = 'top')

yticks(np.linspace(-1,1,5),[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])


ylim(-1.25,+1.25)
show()

# %%
fig = plt.figure() 
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
ax1 = fig.add_axes([0.72, 0.72, 0.16, 0.16]) 
ax2 = fig.add_axes([0.72, 0.52, 0.16, 0.16])
ax3 = fig.add_axes([0.72, 0.32, 0.16, 0.16])
ax3.set_xticks([0,1],['a','b'])
# print(type(ax3) )
ax1.set_title('ax1',fontsize=20)
plt.show()
